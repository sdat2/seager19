# %%
! pip install --upgrade cmip6_preprocessing
! pip install -e ../..
# Out:
# ...
#   Using cached cmip6_preprocessing-0.5.0-py3-none-any.whl (53 kB)
#   Using cached cmip6_preprocessing-0.4.0-py3-none-any.whl (48 kB)
# ...
# Obtaining file:///home/jovyan/seager19
# ...
#   Attempting uninstall: src
#     Found existing installation: src 0.0.1
#     Uninstalling src-0.0.1:
#       Successfully uninstalled src-0.0.1
#   Running setup.py develop for src
# ...

# %%
! zip -r nc_mean.zip nc_mean
# Out:
# updating: nc_mean/ (stored 0%)
# updating: nc_mean/ts.nc (deflated 30%)
# updating: nc_mean/pr.nc (deflated 15%)
# updating: nc_mean/ps.nc (deflated 29%)
# updating: nc_mean/hur.nc (deflated 21%)
# updating: nc_mean/wsp.nc (deflated 17%)
# updating: nc_mean/clt.nc (deflated 20%)

# %%
from src.data_loading.get_cmip6 import GetEnsemble
GetEnsemble(var="ps", output_folder="nc_ps", regen_success_list=True)
# Out:
# NOAA-GFDL
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00<00:00]
#     </div>
# CSIRO-ARCCSS
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# ...

# %%
ls nc_ps
# Out:
# ps.AS-RCEC.TaiESM1.r1i1p1f1.80.nc
# ps.BCC.BCC-CSM2-MR.r1i1p1f1.80.nc
# ps.CAMS.CAMS-CSM1-0.r1i1p1f1.80.nc
# ps.CAMS.CAMS-CSM1-0.r2i1p1f1.80.nc
# ps.CAS.CAS-ESM2-0.r1i1p1f1.80.nc
# ps.CAS.CAS-ESM2-0.r3i1p1f1.80.nc
# ps.CAS.FGOALS-f3-L.r1i1p1f1.80.nc
# ps.CAS.FGOALS-g3.r1i1p1f1.80.nc
# ps.CAS.FGOALS-g3.r2i1p1f1.80.nc
# ps.CAS.FGOALS-g3.r3i1p1f1.80.nc
# ps.CAS.FGOALS-g3.r4i1p1f1.80.nc
# ps.CMCC.CMCC-CM2-SR5.r1i1p1f1.80.nc
# ps.CMCC.CMCC-ESM2.r1i1p1f1.80.nc
# ps.E3SM-Project.E3SM-1-1.r1i1p1f1.80.nc
# ps.FIO-QLNM.FIO-ESM-2-0.r1i1p1f1.80.nc
# ps.FIO-QLNM.FIO-ESM-2-0.r2i1p1f1.80.nc
# ps.FIO-QLNM.FIO-ESM-2-0.r3i1p1f1.80.nc
# ps.INM.INM-CM4-8.r1i1p1f1.80.nc
# ps.INM.INM-CM5-0.r1i1p1f1.80.nc
# ps.KIOST.KIOST-ESM.r1i1p1f1.80.nc
# ps.MOHC.HadGEM3-GC31-LL.r1i1p1f3.80.nc
# ps.MOHC.HadGEM3-GC31-LL.r2i1p1f3.80.nc
# ps.MOHC.HadGEM3-GC31-LL.r3i1p1f3.80.nc
# ps.MOHC.HadGEM3-GC31-LL.r4i1p1f3.80.nc
# ps.MOHC.HadGEM3-GC31-MM.r1i1p1f3.80.nc
# ps.MOHC.HadGEM3-GC31-MM.r2i1p1f3.80.nc
# ...

# %%
ls nc60
# Out:
# ts.AS-RCEC.TaiESM1.r1i1p1f1.60.nc
# ts.BCC.BCC-CSM2-MR.r1i1p1f1.60.nc
# ts.CAMS.CAMS-CSM1-0.r1i1p1f1.60.nc
# ts.CAMS.CAMS-CSM1-0.r2i1p1f1.60.nc
# ts.CAS.CAS-ESM2-0.r1i1p1f1.60.nc
# ts.CAS.CAS-ESM2-0.r3i1p1f1.60.nc
# ts.CAS.FGOALS-f3-L.r1i1p1f1.60.nc
# ts.CAS.FGOALS-g3.r1i1p1f1.60.nc
# ts.CAS.FGOALS-g3.r2i1p1f1.60.nc
# ts.CAS.FGOALS-g3.r3i1p1f1.60.nc
# ts.CAS.FGOALS-g3.r4i1p1f1.60.nc
# ts.CCCR-IITM.IITM-ESM.r1i1p1f1.60.nc
# ts.CMCC.CMCC-CM2-SR5.r1i1p1f1.60.nc
# ts.CMCC.CMCC-ESM2.r1i1p1f1.60.nc
# ts.E3SM-Project.E3SM-1-1.r1i1p1f1.60.nc
# ts.FIO-QLNM.FIO-ESM-2-0.r1i1p1f1.60.nc
# ts.FIO-QLNM.FIO-ESM-2-0.r2i1p1f1.60.nc
# ts.FIO-QLNM.FIO-ESM-2-0.r3i1p1f1.60.nc
# ts.INM.INM-CM4-8.r1i1p1f1.60.nc
# ts.INM.INM-CM5-0.r1i1p1f1.60.nc
# ts.KIOST.KIOST-ESM.r1i1p1f1.60.nc
# ts.MOHC.HadGEM3-GC31-LL.r1i1p1f3.60.nc
# ts.MOHC.HadGEM3-GC31-LL.r2i1p1f3.60.nc
# ts.MOHC.HadGEM3-GC31-LL.r3i1p1f3.60.nc
# ts.MOHC.HadGEM3-GC31-LL.r4i1p1f3.60.nc
# ts.MOHC.HadGEM3-GC31-MM.r1i1p1f3.60.nc
# ...

# %%
GetEnsemble(var="clt", output_folder="nc_clt", regen_success_list=True)
# Out:
# NOAA-GFDL
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00<00:00]
#     </div>
# CSIRO-ARCCSS
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# ...

# %%
GetEnsemble(var="pr", output_folder="nc_pr", regen_success_list=True)
# Out:
# NOAA-GFDL
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2/2 00:00<00:00]
#     </div>
# CSIRO-ARCCSS
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# ...

# %%
from src.data_loading.get_cmip6 import GetEnsemble
GetEnsemble(var="hur", output_folder="nc_hur", regen_success_list=True)

# %%
GetEnsemble(var="uas", output_folder="nc_uas", regen_success_list=True)
# Out:
# ECMWF
# IPSL
# /srv/conda/envs/notebook/lib/python3.8/site-packages/intake_esm/search.py:107: UserWarning: Query returned zero results.
#   warn(message)
# /srv/conda/envs/notebook/lib/python3.8/site-packages/intake_esm/core.py:890: UserWarning: There are no datasets to load! Returning an empty dictionary.
#   warn('There are no datasets to load! Returning an empty dictionary.')
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
# ...
