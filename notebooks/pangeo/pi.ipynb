# %%
! pip install --upgrade cmip6_preprocessing
! pip install -e ../..
! pip install tcpypi
! pip install numba
# Out:
# Requirement already satisfied: cmip6_preprocessing in /srv/conda/envs/notebook/lib/python3.8/site-packages (0.5.0)
# Collecting cmip6_preprocessing
#   Using cached cmip6_preprocessing-0.5.0-py3-none-any.whl (53 kB)
#   Using cached cmip6_preprocessing-0.4.0-py3-none-any.whl (48 kB)
# Requirement already satisfied: xarrayutils in /srv/conda/envs/notebook/lib/python3.8/site-packages (from cmip6_preprocessing) (0.1.3)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.8/site-packages (from cmip6_preprocessing) (1.19.5)
# Requirement already satisfied: xarray in /srv/conda/envs/notebook/lib/python3.8/site-packages (from cmip6_preprocessing) (0.16.2)
# Requirement already satisfied: cftime in /srv/conda/envs/notebook/lib/python3.8/site-packages (from cmip6_preprocessing) (1.4.1)
# Requirement already satisfied: xgcm in /srv/conda/envs/notebook/lib/python3.8/site-packages (from cmip6_preprocessing) (0.5.1)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.8/site-packages (from cmip6_preprocessing) (1.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from pandas->cmip6_preprocessing) (2.7.5)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from pandas->cmip6_preprocessing) (2021.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->cmip6_preprocessing) (1.15.0)
# Requirement already satisfied: setuptools>=38.4 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from xarray->cmip6_preprocessing) (49.6.0.post20210108)
# Requirement already satisfied: dask in /srv/conda/envs/notebook/lib/python3.8/site-packages (from xgcm->cmip6_preprocessing) (2021.1.1)
# Requirement already satisfied: future in /srv/conda/envs/notebook/lib/python3.8/site-packages (from xgcm->cmip6_preprocessing) (0.18.2)
# Requirement already satisfied: docrep<=0.2.7 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from xgcm->cmip6_preprocessing) (0.2.7)
# Requirement already satisfied: pyyaml in /srv/conda/envs/notebook/lib/python3.8/site-packages (from dask->xgcm->cmip6_preprocessing) (5.3.1)
# Obtaining file:///home/jovyan/seager19
# Installing collected packages: src
#   Attempting uninstall: src
#     Found existing installation: src 0.0.1
#     Uninstalling src-0.0.1:
#       Successfully uninstalled src-0.0.1
#   Running setup.py develop for src
# Successfully installed src
# Collecting tcpypi
#   Using cached tcpypi-1.3.4-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy==1.19.5 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from tcpypi) (1.19.5)
# Requirement already satisfied: xarray==0.16.2 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from tcpypi) (0.16.2)
# Collecting numba==0.51.2
#   Using cached numba-0.51.2-cp38-cp38-manylinux2014_x86_64.whl (3.1 MB)
# Collecting llvmlite<0.35,>=0.34.0.dev0
#   Using cached llvmlite-0.34.0-cp38-cp38-manylinux2010_x86_64.whl (24.6 MB)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.8/site-packages (from numba==0.51.2->tcpypi) (49.6.0.post20210108)
# Requirement already satisfied: pandas>=0.25 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from xarray==0.16.2->tcpypi) (1.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from pandas>=0.25->xarray==0.16.2->tcpypi) (2.7.5)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from pandas>=0.25->xarray==0.16.2->tcpypi) (2021.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.25->xarray==0.16.2->tcpypi) (1.15.0)
# Installing collected packages: llvmlite, numba, tcpypi
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.35.0
# ERROR: Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Requirement already satisfied: numba in /srv/conda/envs/notebook/lib/python3.8/site-packages (0.52.0)
# Requirement already satisfied: llvmlite<0.36,>=0.35.0 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from numba) (0.35.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.8/site-packages (from numba) (49.6.0.post20210108)
# Requirement already satisfied: numpy>=1.15 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from numba) (1.19.5)

# %%
! pip install tcpypi

# %%
from tcpyPI import pi
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-aeeff1e3a54d> in <module>
# ----> 1 from tcpyPI import pi
#
# ModuleNotFoundError: No module named 'tcpyPI'

# %%
(VMAX,PMIN,IFL,TO,LNB) = pi(sst1,msl1,p1,t1,q1,CKCD=0.9,ascent_flag=0,diss_flag=1,V_reduc=0.8,miss_handle=0)

# %%
! pip install tcpypi
# Out:
# Collecting tcpypi
#   Using cached tcpypi-1.3.4-py3-none-any.whl (24 kB)
# Collecting numba==0.51.2
#   Using cached numba-0.51.2-cp38-cp38-manylinux2014_x86_64.whl (3.1 MB)
# Requirement already satisfied: numpy==1.19.5 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from tcpypi) (1.19.5)
# Requirement already satisfied: xarray==0.16.2 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from tcpypi) (0.16.2)
# Collecting llvmlite<0.35,>=0.34.0.dev0
#   Using cached llvmlite-0.34.0-cp38-cp38-manylinux2010_x86_64.whl (24.6 MB)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.8/site-packages (from numba==0.51.2->tcpypi) (49.6.0.post20210108)
# Requirement already satisfied: pandas>=0.25 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from xarray==0.16.2->tcpypi) (1.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from pandas>=0.25->xarray==0.16.2->tcpypi) (2.7.5)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from pandas>=0.25->xarray==0.16.2->tcpypi) (2021.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.25->xarray==0.16.2->tcpypi) (1.15.0)
# Installing collected packages: llvmlite, numba, tcpypi
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.35.0
# ERROR: Cannot uninstall 'llvmlite'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
pip freeze
# Out:
# adal @ file:///home/conda/feedstock_root/build_artifacts/adal_1611297630154/work
# adlfs @ file:///home/conda/feedstock_root/build_artifacts/adlfs_1610744724308/work
# affine==2.3.0
# aiobotocore @ file:///home/conda/feedstock_root/build_artifacts/aiobotocore_1610462386154/work
# aiohttp @ file:///home/conda/feedstock_root/build_artifacts/aiohttp_1610358554729/work
# aioitertools @ file:///home/conda/feedstock_root/build_artifacts/aioitertools_1605140085294/work
# alabaster==0.7.12
# alembic @ file:///home/conda/feedstock_root/build_artifacts/alembic_1611966421058/work
# amqp @ file:///home/conda/feedstock_root/build_artifacts/amqp_1611838781267/work
# anyio @ file:///home/conda/feedstock_root/build_artifacts/anyio_1610315727443/work/dist
# appdirs @ file:///home/conda/feedstock_root/build_artifacts/appdirs_1603108395799/work
# argon2-cffi @ file:///home/conda/feedstock_root/build_artifacts/argon2-cffi_1610522574055/work
# asciitree==0.3.3
# asn1crypto @ file:///home/conda/feedstock_root/build_artifacts/asn1crypto_1595949944546/work
# astropy @ file:///home/conda/feedstock_root/build_artifacts/astropy_1610312283340/work
# async-generator==1.10
# async-timeout==3.0.1
# attrs @ file:///home/conda/feedstock_root/build_artifacts/attrs_1605083924122/work
# av @ file:///home/conda/feedstock_root/build_artifacts/av_1611413263935/work
# awscli @ file:///home/conda/feedstock_root/build_artifacts/awscli_1610413726446/work
# azure-core @ file:///home/conda/feedstock_root/build_artifacts/azure-core_1610411593511/work
# azure-datalake-store @ file:///home/conda/feedstock_root/build_artifacts/azure-datalake-store_1602801618978/work
# azure-identity @ file:///home/conda/feedstock_root/build_artifacts/azure-identity_1610098309320/work
# azure-storage-blob @ file:///home/conda/feedstock_root/build_artifacts/azure-storage-blob_1605265963233/work
# Babel @ file:///home/conda/feedstock_root/build_artifacts/babel_1605182336601/work
# backcall @ file:///home/conda/feedstock_root/build_artifacts/backcall_1592338393461/work
# backports.functools-lru-cache==1.6.1
# bcrypt @ file:///home/conda/feedstock_root/build_artifacts/bcrypt_1610521160329/work
# beautifulsoup4 @ file:///home/conda/feedstock_root/build_artifacts/beautifulsoup4_1601745390275/work
# billiard @ file:///home/conda/feedstock_root/build_artifacts/billiard_1602289124896/work
# bleach @ file:///home/conda/feedstock_root/build_artifacts/bleach_1612213472466/work
# blinker==1.4
# blosc @ file:///home/conda/feedstock_root/build_artifacts/python-blosc_1611057023436/work
# bokeh @ file:///home/conda/feedstock_root/build_artifacts/bokeh_1606141192957/work
# boto3 @ file:///home/conda/feedstock_root/build_artifacts/boto3_1610413029640/work
# botocore @ file:///home/conda/feedstock_root/build_artifacts/botocore_1610405652704/work
# Bottleneck @ file:///home/conda/feedstock_root/build_artifacts/bottleneck_1611195606760/work
# branca @ file:///home/conda/feedstock_root/build_artifacts/branca_1609346930842/work
# brotlipy==0.7.0
# cached-property==1.5.1
# cachetools @ file:///home/conda/feedstock_root/build_artifacts/cachetools_1611555765219/work
# cachey @ file:///home/conda/feedstock_root/build_artifacts/cachey_1594854602465/work
# Cartopy @ file:///home/conda/feedstock_root/build_artifacts/cartopy_1608577584950/work
# celery @ file:///home/conda/feedstock_root/build_artifacts/celery_1605090963747/work
# certifi==2020.12.5
# certipy==0.1.3
# cf-xarray @ file:///home/conda/feedstock_root/build_artifacts/cf_xarray_1611331176825/work
# cffi @ file:///home/conda/feedstock_root/build_artifacts/cffi_1606601123836/work
# cfgrib @ file:///home/conda/feedstock_root/build_artifacts/cfgrib_1605218585840/work
# cftime @ file:///home/conda/feedstock_root/build_artifacts/cftime_1612246429007/work
# cgen==2020.1
# chardet @ file:///home/conda/feedstock_root/build_artifacts/chardet_1602255302199/work
# ciso @ file:///home/conda/feedstock_root/build_artifacts/ciso_1610741854206/work
# click==7.1.2
# click-didyoumean==0.0.3
# click-plugins==1.1.1
# click-repl==0.1.6
# cligj @ file:///home/conda/feedstock_root/build_artifacts/cligj_1605902088619/work
# cloudpickle @ file:///home/conda/feedstock_root/build_artifacts/cloudpickle_1598400192773/work
# cmip6-preprocessing==0.5.0
# cmocean==2.0
# colorama==0.4.3
# colorcet @ file:///home/conda/feedstock_root/build_artifacts/colorcet_1611108405642/work
# colorspacious==1.1.2
# configobj==5.0.6
# croniter @ file:///home/conda/feedstock_root/build_artifacts/croniter_1604369816489/work/dist
# cryptography @ file:///home/conda/feedstock_root/build_artifacts/cryptography_1610338667514/work
# cycler==0.10.0
# cytoolz==0.11.0
# dask @ file:///home/conda/feedstock_root/build_artifacts/dask-core_1611349541186/work
# dask-gateway @ file:///home/conda/feedstock_root/build_artifacts/dask-gateway_1604603956844/work/dask-gateway
# dask-glm==0.2.0
# dask-kubernetes @ file:///home/conda/feedstock_root/build_artifacts/dask-kubernetes_1601464522852/work
# dask-labextension @ file:///home/conda/feedstock_root/build_artifacts/dask-labextension_1596807828354/work
# dask-ml @ file:///home/conda/feedstock_root/build_artifacts/dask-ml_1612037053535/work
# datacube @ file:///home/conda/feedstock_root/build_artifacts/datacube_1599029882071/work
# datashader @ file:///home/conda/feedstock_root/build_artifacts/datashader_1610100465364/work
# datashape==0.5.4
# decorator==4.4.2
# defusedxml==0.6.0
# descartes==1.1.0
# distributed @ file:///home/conda/feedstock_root/build_artifacts/distributed_1611361822694/work
# docker @ file:///home/conda/feedstock_root/build_artifacts/docker-py_1611780995811/work
# docker-pycreds==0.4.0
# docopt==0.6.2
# docrep==0.2.7
# docutils @ file:///home/conda/feedstock_root/build_artifacts/docutils_1608044398064/work
# entrypoints @ file:///home/conda/feedstock_root/build_artifacts/entrypoints_1605121927639/work/dist/entrypoints-0.3-py2.py3-none-any.whl
# eofs==1.4.0
# erddapy @ file:///home/conda/feedstock_root/build_artifacts/erddapy_1605211435613/work
# ESMPy==8.0.0
# fastapi @ file:///home/conda/feedstock_root/build_artifacts/fastapi_1610101993319/work
# fasteners==0.14.1
# fastjmd95 @ file:///home/conda/feedstock_root/build_artifacts/fastjmd95_1593201498367/work
# fastprogress @ file:///home/conda/feedstock_root/build_artifacts/fastprogress_1597932925331/work
# Fiona==1.8.18
# fsspec @ file:///home/conda/feedstock_root/build_artifacts/fsspec_1608050797851/work
# future @ file:///home/conda/feedstock_root/build_artifacts/future_1610147327521/work
# gcsfs @ file:///home/conda/feedstock_root/build_artifacts/gcsfs_1599670833394/work
# GDAL==3.1.4
# geocube @ file:///home/conda/feedstock_root/build_artifacts/geocube_1610492845239/work
# geopandas @ file:///home/conda/feedstock_root/build_artifacts/geopandas_1611609867122/work
# geoviews @ file:///home/conda/feedstock_root/build_artifacts/geoviews-core_1600890725326/work
# google-auth @ file:///home/conda/feedstock_root/build_artifacts/google-auth_1608136875028/work
# google-auth-oauthlib @ file:///home/conda/feedstock_root/build_artifacts/google-auth-oauthlib_1603996258953/work
# graphviz @ file:///home/conda/feedstock_root/build_artifacts/python-graphviz_1609966316231/work
# gsw @ file:///home/conda/feedstock_root/build_artifacts/gsw_1602504410563/work
# h11 @ file:///home/conda/feedstock_root/build_artifacts/h11_1609518832927/work
# h5netcdf @ file:///home/conda/feedstock_root/build_artifacts/h5netcdf_1595040520920/work
# h5py @ file:///home/conda/feedstock_root/build_artifacts/h5py_1604753633781/work
# HeapDict==1.0.1
# holoviews @ file:///home/conda/feedstock_root/build_artifacts/holoviews_1609161509779/work
# httptools @ file:///home/conda/feedstock_root/build_artifacts/httptools_1610103349375/work
# hvplot @ file:///home/conda/feedstock_root/build_artifacts/hvplot_1609975327687/work
# idna @ file:///home/conda/feedstock_root/build_artifacts/idna_1593328102638/work
# imagecodecs @ file:///home/conda/feedstock_root/build_artifacts/imagecodecs_1610511162507/work
# imageio @ file:///home/conda/feedstock_root/build_artifacts/imageio_1594044661732/work
# imagesize==1.2.0
# importlib-metadata @ file:///home/conda/feedstock_root/build_artifacts/importlib-metadata_1610355167281/work
# importlib-resources @ file:///home/conda/feedstock_root/build_artifacts/importlib_resources_1611036166509/work
# intake @ file:///home/conda/feedstock_root/build_artifacts/intake_1591213605710/work
# intake-esm @ file:///home/conda/feedstock_root/build_artifacts/intake-esm_1610758614593/work
# intake-geopandas @ file:///home/conda/feedstock_root/build_artifacts/intake-geopandas_1604436964015/work
# intake-stac @ file:///home/conda/feedstock_root/build_artifacts/intake-stac_1602861610470/work
# intake-xarray @ file:///home/conda/feedstock_root/build_artifacts/intake-xarray_1610721485528/work
# ipykernel @ file:///home/conda/feedstock_root/build_artifacts/ipykernel_1607737215242/work/dist/ipykernel-5.4.2-py3-none-any.whl
# ipyleaflet @ file:///home/conda/feedstock_root/build_artifacts/ipyleaflet_1610840544566/work
# ipyspin @ file:///home/conda/feedstock_root/build_artifacts/ipyspin_1610840932555/work
# ipython @ file:///home/conda/feedstock_root/build_artifacts/ipython_1612220454346/work
# ipython-genutils==0.2.0
# ipywidgets @ file:///home/conda/feedstock_root/build_artifacts/ipywidgets_1609995587151/work
# isodate==0.6.0
# jedi @ file:///home/conda/feedstock_root/build_artifacts/jedi_1610146791023/work
# Jinja2 @ file:///home/conda/feedstock_root/build_artifacts/jinja2_1612119311452/work
# jmespath @ file:///home/conda/feedstock_root/build_artifacts/jmespath_1589369830981/work
# joblib @ file:///home/conda/feedstock_root/build_artifacts/joblib_1607956439537/work
# json5 @ file:///home/conda/feedstock_root/build_artifacts/json5_1600692310011/work
# jsonschema @ file:///home/conda/feedstock_root/build_artifacts/jsonschema_1602551949684/work
# jupyter-client @ file:///home/conda/feedstock_root/build_artifacts/jupyter_client_1610375432619/work
# jupyter-core @ file:///home/conda/feedstock_root/build_artifacts/jupyter_core_1612125275706/work
# jupyter-panel-proxy==0.1.0
# jupyter-server @ file:///home/conda/feedstock_root/build_artifacts/jupyter_server_1611092183461/work
# jupyter-server-proxy @ file:///home/conda/feedstock_root/build_artifacts/jupyter-server-proxy_1610317908551/work
# jupyter-telemetry @ file:///home/conda/feedstock_root/build_artifacts/jupyter_telemetry_1605173804246/work
# jupyterhub @ file:///home/conda/feedstock_root/build_artifacts/jupyterhub-feedstock_1607688149914/work
# jupyterlab==2.2.9
# jupyterlab-pygments @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_pygments_1601375948261/work
# jupyterlab-server @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_server_1593951277307/work
# jupyterlab-widgets @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_widgets_1609173350931/work
# kiwisolver @ file:///home/conda/feedstock_root/build_artifacts/kiwisolver_1610099769230/work
# kombu @ file:///home/conda/feedstock_root/build_artifacts/kombu_1604058418932/work
# kubernetes @ file:///home/conda/feedstock_root/build_artifacts/python-kubernetes_1605253606169/work
# kubernetes-asyncio @ file:///home/conda/feedstock_root/build_artifacts/kubernetes_asyncio_1603418924287/work
# lark-parser @ file:///home/conda/feedstock_root/build_artifacts/lark-parser_1605823789759/work
# llvmlite==0.35.0
# locket==0.2.0
# lz4 @ file:///home/conda/feedstock_root/build_artifacts/lz4_1611332391366/work
# Mako @ file:///home/conda/feedstock_root/build_artifacts/mako_1610659158978/work
# Markdown @ file:///home/conda/feedstock_root/build_artifacts/markdown_1603668500820/work
# MarkupSafe @ file:///home/conda/feedstock_root/build_artifacts/markupsafe_1610127565888/work
# marshmallow @ file:///home/conda/feedstock_root/build_artifacts/marshmallow_1608465425564/work
# marshmallow-oneofschema==2.0.1
# matplotlib @ file:///home/conda/feedstock_root/build_artifacts/matplotlib-suite_1611858708474/work
# mercantile @ file:///home/conda/feedstock_root/build_artifacts/mercantile_1598289298975/work
# MetPy @ file:///home/conda/feedstock_root/build_artifacts/metpy_1608625305292/work
# mistune @ file:///home/conda/feedstock_root/build_artifacts/mistune_1610112875388/work
# monotonic==1.5
# mpi4py @ file:///home/conda/feedstock_root/build_artifacts/mpi4py_1611037859652/work
# msal @ file:///home/conda/feedstock_root/build_artifacts/msal_1608108862349/work
# msal-extensions @ file:///home/conda/feedstock_root/build_artifacts/msal_extensions_1599466496699/work
# msgpack @ file:///home/conda/feedstock_root/build_artifacts/msgpack-python_1610121699837/work
# msrest @ file:///home/conda/feedstock_root/build_artifacts/msrest_1611725634474/work
# msrestazure @ file:///home/conda/feedstock_root/build_artifacts/msrestazure_1610096848287/work
# multidict @ file:///home/conda/feedstock_root/build_artifacts/multidict_1610319019165/work
# multipledispatch==0.6.0
# munch==2.5.0
# mypy-extensions @ file:///home/conda/feedstock_root/build_artifacts/mypy_extensions_1610127166133/work
# natsort @ file:///home/conda/feedstock_root/build_artifacts/natsort_1611580267114/work
# nb-conda-kernels @ file:///home/conda/feedstock_root/build_artifacts/nb_conda_kernels_1606762469982/work
# nbclient @ file:///home/conda/feedstock_root/build_artifacts/nbclient_1602859080374/work
# nbconvert @ file:///home/conda/feedstock_root/build_artifacts/nbconvert_1605401836768/work
# nbformat @ file:///home/conda/feedstock_root/build_artifacts/nbformat_1611005694671/work
# nbgitpuller @ file:///home/conda/feedstock_root/build_artifacts/nbgitpuller_1596288711344/work
# nbstripout @ file:///home/conda/feedstock_root/build_artifacts/nbstripout_1593554113964/work
# nc-time-axis==1.2.0
# nest-asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1605195931949/work
# netCDF4 @ file:///home/conda/feedstock_root/build_artifacts/netcdf4_1611263420867/work
# networkx @ file:///home/conda/feedstock_root/build_artifacts/networkx_1598210780226/work
# notebook @ file:///home/conda/feedstock_root/build_artifacts/notebook_1610575313697/work
# numba @ file:///home/conda/feedstock_root/build_artifacts/numba_1607010260266/work
# numcodecs @ file:///home/conda/feedstock_root/build_artifacts/numcodecs_1611651402681/work
# numpy==1.19.5
# oauthlib==3.0.1
# olefile @ file:///home/conda/feedstock_root/build_artifacts/olefile_1602866521163/work
# packaging @ file:///home/conda/feedstock_root/build_artifacts/packaging_1607785313469/work
# pamela==1.0.0
# pandas==1.2.1
# pandocfilters==1.4.2
# panel @ file:///home/conda/feedstock_root/build_artifacts/panel_1610991450506/work
# param @ file:///home/conda/feedstock_root/build_artifacts/param_1610122395674/work
# paramiko @ file:///home/conda/feedstock_root/build_artifacts/paramiko_1598988093657/work
# parcels==2.2.1
# parso @ file:///home/conda/feedstock_root/build_artifacts/parso_1607618318316/work
# partd==1.1.0
# pendulum @ file:///home/conda/feedstock_root/build_artifacts/pendulum_1604871793759/work
# pexpect @ file:///home/conda/feedstock_root/build_artifacts/pexpect_1602535608087/work
# pickleshare @ file:///home/conda/feedstock_root/build_artifacts/pickleshare_1602536217715/work
# Pillow @ file:///home/conda/feedstock_root/build_artifacts/pillow_1610407357749/work
# Pint @ file:///home/conda/feedstock_root/build_artifacts/pint_1601019190097/work
# pooch @ file:///home/conda/feedstock_root/build_artifacts/pooch_1606467285986/work
# portalocker @ file:///home/conda/feedstock_root/build_artifacts/portalocker_1610360239318/work
# prefect @ file:///home/conda/feedstock_root/build_artifacts/prefect_1611715598636/work
# progressbar2 @ file:///home/conda/feedstock_root/build_artifacts/progressbar2_1599661727525/work
# prometheus-client @ file:///home/conda/feedstock_root/build_artifacts/prometheus_client_1605543085815/work
# prompt-toolkit @ file:///home/conda/feedstock_root/build_artifacts/prompt-toolkit_1611605286670/work
# psutil @ file:///home/conda/feedstock_root/build_artifacts/psutil_1610127095720/work
# psycopg2 @ file:///home/conda/feedstock_root/build_artifacts/psycopg2_1608904129475/work
# ptyprocess @ file:///home/conda/feedstock_root/build_artifacts/ptyprocess_1609419310487/work/dist/ptyprocess-0.7.0-py2.py3-none-any.whl
# pyarrow==3.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.7
# pycamhd==0.7.0
# pycparser @ file:///home/conda/feedstock_root/build_artifacts/pycparser_1593275161868/work
# pyct==0.4.6
# pycurl==7.43.0.6
# pydantic @ file:///home/conda/feedstock_root/build_artifacts/pydantic_1606818635778/work
# Pydap @ file:///home/conda/feedstock_root/build_artifacts/pydap_1602635529734/work
# pyerfa @ file:///home/conda/feedstock_root/build_artifacts/pyerfa_1610303624151/work
# Pygments @ file:///home/conda/feedstock_root/build_artifacts/pygments_1610742651773/work
# PyJWT==1.7.1
# pykdtree @ file:///home/conda/feedstock_root/build_artifacts/pykdtree_1605125560495/work
# pymbolic==2020.1
# PyNaCl @ file:///home/conda/feedstock_root/build_artifacts/pynacl_1610673137600/work
# pyOpenSSL @ file:///home/conda/feedstock_root/build_artifacts/pyopenssl_1608055815057/work
# pyorbital @ file:///home/conda/feedstock_root/build_artifacts/pyorbital_1593006728607/work
# pyparsing==2.4.7
# pyproj @ file:///home/conda/feedstock_root/build_artifacts/pyproj_1602664229713/work
# PyQt5==5.12.3
# PyQt5-sip==4.19.18
# PyQtChart==5.12
# PyQtWebEngine==5.12.1
# pyresample @ file:///home/conda/feedstock_root/build_artifacts/pyresample_1605215644445/work
# pyrsistent @ file:///home/conda/feedstock_root/build_artifacts/pyrsistent_1610146798212/work
# pyshp @ file:///home/conda/feedstock_root/build_artifacts/pyshp_1610646860606/work
# PySocks @ file:///home/conda/feedstock_root/build_artifacts/pysocks_1610291447907/work
# pyspectral @ file:///home/conda/feedstock_root/build_artifacts/pyspectral_1607381925455/work
# pystac @ file:///home/conda/feedstock_root/build_artifacts/pystac_1610680440515/work
# python-box @ file:///home/conda/feedstock_root/build_artifacts/python-box_1603943657432/work
# python-dateutil==2.7.5
# python-dotenv @ file:///home/conda/feedstock_root/build_artifacts/python-dotenv_1603979006023/work
# python-editor==1.0.4
# python-geotiepoints @ file:///home/conda/feedstock_root/build_artifacts/python-geotiepoints_1591420588258/work
# python-gist==0.9.2
# python-gnupg @ file:///home/conda/feedstock_root/build_artifacts/python-gnupg_1595950493201/work
# python-json-logger @ file:///home/conda/feedstock_root/build_artifacts/python-json-logger_1602545356084/work
# python-slugify @ file:///home/conda/feedstock_root/build_artifacts/python-slugify_1593573453419/work
# python-utils @ file:///home/conda/feedstock_root/build_artifacts/python-utils_1611682172206/work
# pytools @ file:///home/conda/feedstock_root/build_artifacts/pytools_1610227461013/work
# pytz @ file:///home/conda/feedstock_root/build_artifacts/pytz_1612179539967/work
# pytzdata @ file:///home/conda/feedstock_root/build_artifacts/pytzdata_1594644346367/work
# pyviz-comms @ file:///home/conda/feedstock_root/build_artifacts/pyviz_comms_1609149992420/work
# PyWavelets @ file:///home/conda/feedstock_root/build_artifacts/pywavelets_1607290812047/work
# PyYAML==5.3.1
# pyzmq @ file:///home/conda/feedstock_root/build_artifacts/pyzmq_1611924182870/work
# rasterio @ file:///home/conda/feedstock_root/build_artifacts/rasterio_1611604219309/work
# rechunker @ file:///home/conda/feedstock_root/build_artifacts/rechunker_1610739435124/work
# redis @ file:///home/conda/feedstock_root/build_artifacts/redis-py_1591044931092/work
# requests @ file:///home/conda/feedstock_root/build_artifacts/requests_1608156231189/work
# requests-oauthlib @ file:///home/conda/feedstock_root/build_artifacts/requests-oauthlib_1595492159598/work
# rio-cogeo @ file:///home/conda/feedstock_root/build_artifacts/rio-cogeo_1602112245615/work
# rioxarray @ file:///home/conda/feedstock_root/build_artifacts/rioxarray_1612225142857/work
# rsa @ file:///home/conda/feedstock_root/build_artifacts/rsa_1591990902901/work
# Rtree @ file:///home/conda/feedstock_root/build_artifacts/rtree_1610147130400/work
# ruamel.yaml @ file:///home/conda/feedstock_root/build_artifacts/ruamel.yaml_1610291375472/work
# ruamel.yaml.clib @ file:///home/conda/feedstock_root/build_artifacts/ruamel.yaml.clib_1610146840614/work
# s3fs @ file:///home/conda/feedstock_root/build_artifacts/s3fs_1608058532532/work
# s3transfer @ file:///home/conda/feedstock_root/build_artifacts/s3transfer_1610404472418/work
# sat-search @ file:///home/conda/feedstock_root/build_artifacts/sat-search_1598209091152/work
# sat-stac @ file:///home/conda/feedstock_root/build_artifacts/sat-stac_1611559252873/work
# satpy @ file:///home/conda/feedstock_root/build_artifacts/satpy_1610031861065/work
# scikit-image==0.18.1
# scikit-learn @ file:///home/conda/feedstock_root/build_artifacts/scikit-learn_1611079738450/work
# scipy @ file:///home/conda/feedstock_root/build_artifacts/scipy_1609457852787/work
# Send2Trash==1.5.0
# Shapely @ file:///home/conda/feedstock_root/build_artifacts/shapely_1611317103512/work
# simpervisor @ file:///home/conda/feedstock_root/build_artifacts/simpervisor_1609865618711/work
# simplejson @ file:///home/conda/feedstock_root/build_artifacts/simplejson_1610147072101/work
# six @ file:///home/conda/feedstock_root/build_artifacts/six_1590081179328/work
# sniffio @ file:///home/conda/feedstock_root/build_artifacts/sniffio_1610318319305/work
# snowballstemmer @ file:///home/conda/feedstock_root/build_artifacts/snowballstemmer_1611270869511/work
# snuggs==1.4.7
# sortedcontainers @ file:///home/conda/feedstock_root/build_artifacts/sortedcontainers_1605110889605/work
# soupsieve @ file:///home/conda/feedstock_root/build_artifacts/soupsieve_1597680516047/work
# sparse @ file:///home/conda/feedstock_root/build_artifacts/sparse_1599220939296/work
# Sphinx @ file:///home/conda/feedstock_root/build_artifacts/sphinx_1610040422307/work
# sphinxcontrib-applehelp==1.0.2
# sphinxcontrib-devhelp==1.0.2
# sphinxcontrib-htmlhelp==1.0.3
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.3
# sphinxcontrib-serializinghtml==1.1.4
# SQLAlchemy @ file:///home/conda/feedstock_root/build_artifacts/sqlalchemy_1612225077951/work
# -e git+https://github.com/sdat2/seager19.git@f6fbb5294b2192ae1bffb3ae1705174b1a05e5cd#egg=src
# sshtunnel @ file:///home/conda/feedstock_root/build_artifacts/sshtunnel_1605516234669/work
# starlette @ file:///home/conda/feedstock_root/build_artifacts/starlette_1595508258730/work
# supermercado @ file:///home/conda/feedstock_root/build_artifacts/supermercado_1602706127414/work
# tabulate==0.8.7
# tblib==1.6.0
# terminado @ file:///home/conda/feedstock_root/build_artifacts/terminado_1609794172745/work
# testpath==0.4.4
# text-unidecode==1.3
# threadpoolctl @ file:///tmp/tmp79xdzxkt/threadpoolctl-2.1.0-py3-none-any.whl
# tifffile @ file:///home/conda/feedstock_root/build_artifacts/tifffile_1612264465539/work
# tiledb==0.7.7
# toml @ file:///home/conda/feedstock_root/build_artifacts/toml_1604308577558/work
# toolz @ file:///home/conda/feedstock_root/build_artifacts/toolz_1600973991856/work
# tornado @ file:///home/conda/feedstock_root/build_artifacts/tornado_1610094706440/work
# tqdm @ file:///home/conda/feedstock_root/build_artifacts/tqdm_1610419111160/work
# traitlets @ file:///home/conda/feedstock_root/build_artifacts/traitlets_1602771532708/work
# traittypes @ file:///home/conda/feedstock_root/build_artifacts/traittypes_1600843364635/work
# trollimage @ file:///home/conda/feedstock_root/build_artifacts/trollimage_1600434241265/work
# trollsift==0.3.4
# typing-extensions @ file:///home/conda/feedstock_root/build_artifacts/typing_extensions_1602702424206/work
# Unidecode @ file:///home/conda/feedstock_root/build_artifacts/unidecode_1608471621084/work
# urllib3 @ file:///home/conda/feedstock_root/build_artifacts/urllib3_1611695416663/work
# uvicorn @ file:///home/conda/feedstock_root/build_artifacts/uvicorn_1609266493894/work
# uvloop==0.14.0
# vine @ file:///home/conda/feedstock_root/build_artifacts/vine_1604930048994/work
# watchgod @ file:///home/conda/feedstock_root/build_artifacts/watchgod_1592453122359/work
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1600965781394/work
# webencodings==0.5.1
# WebOb==1.8.6
# websocket-client @ file:///home/conda/feedstock_root/build_artifacts/websocket-client_1610127644879/work
# websockets @ file:///home/conda/feedstock_root/build_artifacts/websockets_1610127459535/work
# widgetsnbextension @ file:///home/conda/feedstock_root/build_artifacts/widgetsnbextension_1605475534911/work
# wrapt @ file:///home/conda/feedstock_root/build_artifacts/wrapt_1610094884173/work
# xarray @ file:///home/conda/feedstock_root/build_artifacts/xarray_1606798576866/work
# xarray-leaflet @ file:///home/conda/feedstock_root/build_artifacts/xarray_leaflet_1605101335893/work
# xarray-spatial @ file:///home/conda/feedstock_root/build_artifacts/xarray-spatial_1606884345273/work
# xarrayutils==0.1.3
# xcape @ file:///home/conda/feedstock_root/build_artifacts/xcape_1604152379335/work
# xcube==0.2.1
# xesmf @ file:///home/conda/feedstock_root/build_artifacts/xesmf_1610407484436/work
# xgcm @ file:///home/conda/feedstock_root/build_artifacts/xgcm_1602912632107/work
# xhistogram @ file:///home/conda/feedstock_root/build_artifacts/xhistogram_1607625576907/work
# xlayers @ file:///home/conda/feedstock_root/build_artifacts/xlayers_1602868905323/work
# xmitgcm @ file:///home/conda/feedstock_root/build_artifacts/xmitgcm_1606247192291/work
# xpublish @ file:///home/conda/feedstock_root/build_artifacts/xpublish_1597250910776/work
# xrft @ file:///home/conda/feedstock_root/build_artifacts/xrft_1605547540409/work
# yarl @ file:///home/conda/feedstock_root/build_artifacts/yarl_1610354134018/work
# zarr @ file:///home/conda/feedstock_root/build_artifacts/zarr_1606962441855/work
# zict==2.0.0
# zipp @ file:///home/conda/feedstock_root/build_artifacts/zipp_1603668650351/work
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-0336de56043d> in <module>
# ----> 1 import tcpyPI
#
# ModuleNotFoundError: No module named 'tcpyPI'
