# %% [markdown]
# # Analysis

# %%
# Convenient jupyter setup
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.greedy=True

# %%
# set up plotting settings for dark mode.
from jupyterthemes import jtplot
jtplot.style(theme="grade3", context="notebook", ticks=True, grid=False)
from src.plot_settings import ps_defaults
ps_defaults(use_tex=False, dpi=150)

# %%
import xarray as xr
from src.constants import FIGURE_DATA_PATH

# %%
print(xr.open_dataset(FIGURE_DATA_PATH))
# Out:
# <xarray.Dataset>
# Dimensions:                                         (X: 180, X_01: 360, X_02: 359, Y: 161, Y_01: 160, Yu: 59, Yv: 60, lat: 121, lon: 360)
# Coordinates:
#   * X                                               (X) float32 0.0 ... 358.0
#   * Yu                                              (Yu) float32 -58.0 ... 58.0
#   * Yv                                              (Yv) float32 -59.0 ... 59.0
#   * X_01                                            (X_01) float32 0.0 ... 359.0
#   * Y                                               (Y) float32 -80.0 ... 80.0
#   * lat                                             (lat) float32 -60.0 ... 60.0
#   * lon                                             (lon) float32 0.0 ... 359.0
#   * X_02                                            (X_02) float32 0.5 ... 358.5
#   * Y_01                                            (Y_01) float32 -79.5 ... ...
# Data variables: (12/125)
#     CoupledModel.Fig_3.nc.epsu                      timedelta64[ns] ...
#     CoupledModel.Fig_3.nc.epsv                      timedelta64[ns] ...
#     CoupledModel.Fig_3.nc.Hq                        float32 ...
#     CoupledModel.Fig_3.nc.K                         timedelta64[ns] ...
#     CoupledModel.Fig_3.nc.mask                      (Yu, X) float64 ...
#     CoupledModel.Fig_3.nc.phitrend                  (Yu, X) float64 ...
#     ...                                              ...
#     ForcedAtmosphereModel.Fig_2d.nc.vtrend          (Yv, X) float64 ...
#     ForcedAtmosphereModel.Fig_2d.nc.wnspClim        (Yu, X) float64 ...
#     ForcedOceanModel.HTHERM-trend-Fig_4b.nc.HTHERM  (Y, X_01) float64 ...
#     ForcedOceanModel.sst-trend-Fig_1d.nc.SST        (Y_01, X_02) float64 ...
#     ForcedOceanModel.sst-trend-Fig_1e.nc.SST        (Y_01, X_02) float64 ...
#     ForcedOceanModel.sst-trend-Fig_1f.nc.SST        (Y_01, X_02) float64 ...
# Attributes: (12/17)
#     CoupledModel.description:                       Coupled model results in ...
#     CoupledModel.Fig_3.nc.NCO:                      4.3.7
#     CoupledModel.Fig_3.nc._NCProperties:            version=1|netcdflibversio...
#     CoupledModel.Fig_5a.nc.NCO:                     4.3.7
#     CoupledModel.Fig_5a.nc._NCProperties:           version=1|netcdflibversio...
#     CoupledModel.Fig_5b.nc.NCO:                     4.3.7
#     ...                                             ...
#     ForcedAtmosphereModel.description:              Model results in Figure 2c,d
#     ForcedAtmosphereModel.Fig_2c.nc.NCO:            4.3.7
#     ForcedAtmosphereModel.Fig_2c.nc._NCProperties:  version=1|netcdflibversio...
#     ForcedAtmosphereModel.Fig_2d.nc.NCO:            4.3.7
#     ForcedAtmosphereModel.Fig_2d.nc._NCProperties:  version=1|netcdflibversio...
#     ForcedOceanModel.description:                   Model results in Figures ...

# %%
for var in xr.open_dataset(FIGURE_DATA_PATH):
    print(var)
# Out:
# CoupledModel.Fig_3.nc.epsu
# <class 'str'>
# CoupledModel.Fig_3.nc.epsv
# <class 'str'>
# CoupledModel.Fig_3.nc.Hq
# <class 'str'>
# CoupledModel.Fig_3.nc.K
# <class 'str'>
# CoupledModel.Fig_3.nc.mask
# <class 'str'>
# CoupledModel.Fig_3.nc.phitrend
# <class 'str'>
# CoupledModel.Fig_3.nc.prClim
# <class 'str'>
# CoupledModel.Fig_3.nc.PRtrend
# <class 'str'>
# CoupledModel.Fig_3.nc.prTrend
# <class 'str'>
# CoupledModel.Fig_3.nc.Qthtrend
# <class 'str'>
# CoupledModel.Fig_3.nc.spClim
# <class 'str'>
# CoupledModel.Fig_3.nc.tsClim
# <class 'str'>
# CoupledModel.Fig_3.nc.tsTrend
# <class 'str'>
# CoupledModel.Fig_3.nc.tstrend
# <class 'str'>
# CoupledModel.Fig_3.nc.utrend
# <class 'str'>
# CoupledModel.Fig_3.nc.vtrend
# <class 'str'>
# CoupledModel.Fig_3.nc.wnspClim
# <class 'str'>
# CoupledModel.Fig_5a.nc.epsu
# <class 'str'>
# CoupledModel.Fig_5a.nc.epsv
# <class 'str'>
# CoupledModel.Fig_5a.nc.Hq
# <class 'str'>
# CoupledModel.Fig_5a.nc.K
# <class 'str'>
# CoupledModel.Fig_5a.nc.mask
# <class 'str'>
# CoupledModel.Fig_5a.nc.phitrend
# <class 'str'>
# CoupledModel.Fig_5a.nc.prClim
# <class 'str'>
# CoupledModel.Fig_5a.nc.PRtrend
# <class 'str'>
# CoupledModel.Fig_5a.nc.prTrend
# <class 'str'>
# CoupledModel.Fig_5a.nc.Qthtrend
# <class 'str'>
# CoupledModel.Fig_5a.nc.spClim
# <class 'str'>
# CoupledModel.Fig_5a.nc.tsClim
# <class 'str'>
# CoupledModel.Fig_5a.nc.tsTrend
# <class 'str'>
# CoupledModel.Fig_5a.nc.tstrend
# <class 'str'>
# CoupledModel.Fig_5a.nc.utrend
# <class 'str'>
# CoupledModel.Fig_5a.nc.vtrend
# <class 'str'>
# CoupledModel.Fig_5a.nc.wnspClim
# <class 'str'>
# CoupledModel.Fig_5b.nc.epsu
# <class 'str'>
# CoupledModel.Fig_5b.nc.epsv
# <class 'str'>
# CoupledModel.Fig_5b.nc.Hq
# <class 'str'>
# CoupledModel.Fig_5b.nc.K
# <class 'str'>
# CoupledModel.Fig_5b.nc.mask
# <class 'str'>
# CoupledModel.Fig_5b.nc.phitrend
# <class 'str'>
# CoupledModel.Fig_5b.nc.prClim
# <class 'str'>
# CoupledModel.Fig_5b.nc.PRtrend
# <class 'str'>
# CoupledModel.Fig_5b.nc.prTrend
# <class 'str'>
# CoupledModel.Fig_5b.nc.Qthtrend
# <class 'str'>
# CoupledModel.Fig_5b.nc.spClim
# <class 'str'>
# CoupledModel.Fig_5b.nc.tsClim
# <class 'str'>
# CoupledModel.Fig_5b.nc.tsTrend
# <class 'str'>
# CoupledModel.Fig_5b.nc.tstrend
# <class 'str'>
# CoupledModel.Fig_5b.nc.utrend
# <class 'str'>
# CoupledModel.Fig_5b.nc.vtrend
# <class 'str'>
# CoupledModel.Fig_5b.nc.wnspClim
# <class 'str'>
# CoupledModel.Fig_5c.nc.epsu
# <class 'str'>
# CoupledModel.Fig_5c.nc.epsv
# <class 'str'>
# CoupledModel.Fig_5c.nc.Hq
# <class 'str'>
# CoupledModel.Fig_5c.nc.K
# <class 'str'>
# CoupledModel.Fig_5c.nc.mask
# <class 'str'>
# CoupledModel.Fig_5c.nc.phitrend
# <class 'str'>
# CoupledModel.Fig_5c.nc.prClim
# <class 'str'>
# CoupledModel.Fig_5c.nc.PRtrend
# <class 'str'>
# CoupledModel.Fig_5c.nc.prTrend
# <class 'str'>
# CoupledModel.Fig_5c.nc.Qthtrend
# <class 'str'>
# CoupledModel.Fig_5c.nc.spClim
# <class 'str'>
# CoupledModel.Fig_5c.nc.tsClim
# <class 'str'>
# CoupledModel.Fig_5c.nc.tsTrend
# <class 'str'>
# CoupledModel.Fig_5c.nc.tstrend
# <class 'str'>
# CoupledModel.Fig_5c.nc.utrend
# <class 'str'>
# CoupledModel.Fig_5c.nc.vtrend
# <class 'str'>
# CoupledModel.Fig_5c.nc.wnspClim
# <class 'str'>
# CoupledModel.Fig_5d.nc.epsu
# <class 'str'>
# CoupledModel.Fig_5d.nc.epsv
# <class 'str'>
# CoupledModel.Fig_5d.nc.Hq
# <class 'str'>
# CoupledModel.Fig_5d.nc.K
# <class 'str'>
# CoupledModel.Fig_5d.nc.mask
# <class 'str'>
# CoupledModel.Fig_5d.nc.phitrend
# <class 'str'>
# CoupledModel.Fig_5d.nc.prClim
# <class 'str'>
# CoupledModel.Fig_5d.nc.PRtrend
# <class 'str'>
# CoupledModel.Fig_5d.nc.prTrend
# <class 'str'>
# CoupledModel.Fig_5d.nc.Qthtrend
# <class 'str'>
# CoupledModel.Fig_5d.nc.spClim
# <class 'str'>
# CoupledModel.Fig_5d.nc.tsClim
# <class 'str'>
# CoupledModel.Fig_5d.nc.tsTrend
# <class 'str'>
# CoupledModel.Fig_5d.nc.tstrend
# <class 'str'>
# CoupledModel.Fig_5d.nc.utrend
# <class 'str'>
# CoupledModel.Fig_5d.nc.vtrend
# <class 'str'>
# CoupledModel.Fig_5d.nc.wnspClim
# <class 'str'>
# CoupledModel.HTHERM-trend-Fig_4c.nc.HTHERM
# <class 'str'>
# CoupledModel.HTHERM-trend-Fig_5f.nc.HTHERM
# <class 'str'>
# CoupledModel.rh-Fig_5a.nc.rh
# <class 'str'>
# CoupledModel.rh-Fig_5b.nc.rh
# <class 'str'>
# CoupledModel.rh-Fig_5c.nc.rh
# <class 'str'>
# CoupledModel.rh-Fig_5d.nc.rh
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.epsu
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.epsv
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.Hq
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.K
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.mask
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.phitrend
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.prClim
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.PRtrend
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.Qthtrend
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.spClim
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.tsClim
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.tstrend
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.utrend
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.vtrend
# <class 'str'>
# ForcedAtmosphereModel.Fig_2c.nc.wnspClim
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.epsu
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.epsv
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.Hq
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.K
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.mask
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.phitrend
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.prClim
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.PRtrend
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.Qthtrend
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.spClim
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.tsClim
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.tstrend
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.utrend
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.vtrend
# <class 'str'>
# ForcedAtmosphereModel.Fig_2d.nc.wnspClim
# <class 'str'>
# ForcedOceanModel.HTHERM-trend-Fig_4b.nc.HTHERM
# <class 'str'>
# ForcedOceanModel.sst-trend-Fig_1d.nc.SST
# <class 'str'>
# ForcedOceanModel.sst-trend-Fig_1e.nc.SST
# <class 'str'>
# ForcedOceanModel.sst-trend-Fig_1f.nc.SST
# <class 'str'>

# %%
var_list = [var for var in xr.open_dataset(FIGURE_DATA_PATH)]

# %%
for i in range(1, 7):
    print([var for var in var_list if "Fig_" + str(i) in var])
# Out:
# ['ForcedOceanModel.sst-trend-Fig_1d.nc.SST', 'ForcedOceanModel.sst-trend-Fig_1e.nc.SST', 'ForcedOceanModel.sst-trend-Fig_1f.nc.SST']
# ['ForcedAtmosphereModel.Fig_2c.nc.epsu', 'ForcedAtmosphereModel.Fig_2c.nc.epsv', 'ForcedAtmosphereModel.Fig_2c.nc.Hq', 'ForcedAtmosphereModel.Fig_2c.nc.K', 'ForcedAtmosphereModel.Fig_2c.nc.mask', 'ForcedAtmosphereModel.Fig_2c.nc.phitrend', 'ForcedAtmosphereModel.Fig_2c.nc.prClim', 'ForcedAtmosphereModel.Fig_2c.nc.PRtrend', 'ForcedAtmosphereModel.Fig_2c.nc.Qthtrend', 'ForcedAtmosphereModel.Fig_2c.nc.spClim', 'ForcedAtmosphereModel.Fig_2c.nc.tsClim', 'ForcedAtmosphereModel.Fig_2c.nc.tstrend', 'ForcedAtmosphereModel.Fig_2c.nc.utrend', 'ForcedAtmosphereModel.Fig_2c.nc.vtrend', 'ForcedAtmosphereModel.Fig_2c.nc.wnspClim', 'ForcedAtmosphereModel.Fig_2d.nc.epsu', 'ForcedAtmosphereModel.Fig_2d.nc.epsv', 'ForcedAtmosphereModel.Fig_2d.nc.Hq', 'ForcedAtmosphereModel.Fig_2d.nc.K', 'ForcedAtmosphereModel.Fig_2d.nc.mask', 'ForcedAtmosphereModel.Fig_2d.nc.phitrend', 'ForcedAtmosphereModel.Fig_2d.nc.prClim', 'ForcedAtmosphereModel.Fig_2d.nc.PRtrend', 'ForcedAtmosphereModel.Fig_2d.nc.Qthtrend', 'ForcedAtmosphereModel.Fig_2d.nc.spClim', 'ForcedAtmosphereModel.Fig_2d.nc.tsClim', 'ForcedAtmosphereModel.Fig_2d.nc.tstrend', 'ForcedAtmosphereModel.Fig_2d.nc.utrend', 'ForcedAtmosphereModel.Fig_2d.nc.vtrend', 'ForcedAtmosphereModel.Fig_2d.nc.wnspClim']
# ['CoupledModel.Fig_3.nc.epsu', 'CoupledModel.Fig_3.nc.epsv', 'CoupledModel.Fig_3.nc.Hq', 'CoupledModel.Fig_3.nc.K', 'CoupledModel.Fig_3.nc.mask', 'CoupledModel.Fig_3.nc.phitrend', 'CoupledModel.Fig_3.nc.prClim', 'CoupledModel.Fig_3.nc.PRtrend', 'CoupledModel.Fig_3.nc.prTrend', 'CoupledModel.Fig_3.nc.Qthtrend', 'CoupledModel.Fig_3.nc.spClim', 'CoupledModel.Fig_3.nc.tsClim', 'CoupledModel.Fig_3.nc.tsTrend', 'CoupledModel.Fig_3.nc.tstrend', 'CoupledModel.Fig_3.nc.utrend', 'CoupledModel.Fig_3.nc.vtrend', 'CoupledModel.Fig_3.nc.wnspClim']
# ['CoupledModel.HTHERM-trend-Fig_4c.nc.HTHERM', 'ForcedOceanModel.HTHERM-trend-Fig_4b.nc.HTHERM']
# ['CoupledModel.Fig_5a.nc.epsu', 'CoupledModel.Fig_5a.nc.epsv', 'CoupledModel.Fig_5a.nc.Hq', 'CoupledModel.Fig_5a.nc.K', 'CoupledModel.Fig_5a.nc.mask', 'CoupledModel.Fig_5a.nc.phitrend', 'CoupledModel.Fig_5a.nc.prClim', 'CoupledModel.Fig_5a.nc.PRtrend', 'CoupledModel.Fig_5a.nc.prTrend', 'CoupledModel.Fig_5a.nc.Qthtrend', 'CoupledModel.Fig_5a.nc.spClim', 'CoupledModel.Fig_5a.nc.tsClim', 'CoupledModel.Fig_5a.nc.tsTrend', 'CoupledModel.Fig_5a.nc.tstrend', 'CoupledModel.Fig_5a.nc.utrend', 'CoupledModel.Fig_5a.nc.vtrend', 'CoupledModel.Fig_5a.nc.wnspClim', 'CoupledModel.Fig_5b.nc.epsu', 'CoupledModel.Fig_5b.nc.epsv', 'CoupledModel.Fig_5b.nc.Hq', 'CoupledModel.Fig_5b.nc.K', 'CoupledModel.Fig_5b.nc.mask', 'CoupledModel.Fig_5b.nc.phitrend', 'CoupledModel.Fig_5b.nc.prClim', 'CoupledModel.Fig_5b.nc.PRtrend', 'CoupledModel.Fig_5b.nc.prTrend', 'CoupledModel.Fig_5b.nc.Qthtrend', 'CoupledModel.Fig_5b.nc.spClim', 'CoupledModel.Fig_5b.nc.tsClim', 'CoupledModel.Fig_5b.nc.tsTrend', 'CoupledModel.Fig_5b.nc.tstrend', 'CoupledModel.Fig_5b.nc.utrend', 'CoupledModel.Fig_5b.nc.vtrend', 'CoupledModel.Fig_5b.nc.wnspClim', 'CoupledModel.Fig_5c.nc.epsu', 'CoupledModel.Fig_5c.nc.epsv', 'CoupledModel.Fig_5c.nc.Hq', 'CoupledModel.Fig_5c.nc.K', 'CoupledModel.Fig_5c.nc.mask', 'CoupledModel.Fig_5c.nc.phitrend', 'CoupledModel.Fig_5c.nc.prClim', 'CoupledModel.Fig_5c.nc.PRtrend', 'CoupledModel.Fig_5c.nc.prTrend', 'CoupledModel.Fig_5c.nc.Qthtrend', 'CoupledModel.Fig_5c.nc.spClim', 'CoupledModel.Fig_5c.nc.tsClim', 'CoupledModel.Fig_5c.nc.tsTrend', 'CoupledModel.Fig_5c.nc.tstrend', 'CoupledModel.Fig_5c.nc.utrend', 'CoupledModel.Fig_5c.nc.vtrend', 'CoupledModel.Fig_5c.nc.wnspClim', 'CoupledModel.Fig_5d.nc.epsu', 'CoupledModel.Fig_5d.nc.epsv', 'CoupledModel.Fig_5d.nc.Hq', 'CoupledModel.Fig_5d.nc.K', 'CoupledModel.Fig_5d.nc.mask', 'CoupledModel.Fig_5d.nc.phitrend', 'CoupledModel.Fig_5d.nc.prClim', 'CoupledModel.Fig_5d.nc.PRtrend', 'CoupledModel.Fig_5d.nc.prTrend', 'CoupledModel.Fig_5d.nc.Qthtrend', 'CoupledModel.Fig_5d.nc.spClim', 'CoupledModel.Fig_5d.nc.tsClim', 'CoupledModel.Fig_5d.nc.tsTrend', 'CoupledModel.Fig_5d.nc.tstrend', 'CoupledModel.Fig_5d.nc.utrend', 'CoupledModel.Fig_5d.nc.vtrend', 'CoupledModel.Fig_5d.nc.wnspClim', 'CoupledModel.HTHERM-trend-Fig_5f.nc.HTHERM', 'CoupledModel.rh-Fig_5a.nc.rh', 'CoupledModel.rh-Fig_5b.nc.rh', 'CoupledModel.rh-Fig_5c.nc.rh', 'CoupledModel.rh-Fig_5d.nc.rh']
# []

# %%
[var for var in var_list if "Fig_3" in var]
# Out:
# ['CoupledModel.Fig_3.nc.epsu',
#  'CoupledModel.Fig_3.nc.epsv',
#  'CoupledModel.Fig_3.nc.Hq',
#  'CoupledModel.Fig_3.nc.K',
#  'CoupledModel.Fig_3.nc.mask',
#  'CoupledModel.Fig_3.nc.phitrend',
#  'CoupledModel.Fig_3.nc.prClim',
#  'CoupledModel.Fig_3.nc.PRtrend',
#  'CoupledModel.Fig_3.nc.prTrend',
#  'CoupledModel.Fig_3.nc.Qthtrend',
#  'CoupledModel.Fig_3.nc.spClim',
#  'CoupledModel.Fig_3.nc.tsClim',
#  'CoupledModel.Fig_3.nc.tsTrend',
#  'CoupledModel.Fig_3.nc.tstrend',
#  'CoupledModel.Fig_3.nc.utrend',
#  'CoupledModel.Fig_3.nc.vtrend',
#  'CoupledModel.Fig_3.nc.wnspClim']

# %%
var_list
# Out:
# ['CoupledModel.Fig_3.nc.epsu',
#  'CoupledModel.Fig_3.nc.epsv',
#  'CoupledModel.Fig_3.nc.Hq',
#  'CoupledModel.Fig_3.nc.K',
#  'CoupledModel.Fig_3.nc.mask',
#  'CoupledModel.Fig_3.nc.phitrend',
#  'CoupledModel.Fig_3.nc.prClim',
#  'CoupledModel.Fig_3.nc.PRtrend',
#  'CoupledModel.Fig_3.nc.prTrend',
#  'CoupledModel.Fig_3.nc.Qthtrend',
#  'CoupledModel.Fig_3.nc.spClim',
#  'CoupledModel.Fig_3.nc.tsClim',
#  'CoupledModel.Fig_3.nc.tsTrend',
#  'CoupledModel.Fig_3.nc.tstrend',
#  'CoupledModel.Fig_3.nc.utrend',
#  'CoupledModel.Fig_3.nc.vtrend',
#  'CoupledModel.Fig_3.nc.wnspClim',
#  'CoupledModel.Fig_5a.nc.epsu',
#  'CoupledModel.Fig_5a.nc.epsv',
#  'CoupledModel.Fig_5a.nc.Hq',
#  'CoupledModel.Fig_5a.nc.K',
#  'CoupledModel.Fig_5a.nc.mask',
#  'CoupledModel.Fig_5a.nc.phitrend',
#  'CoupledModel.Fig_5a.nc.prClim',
#  'CoupledModel.Fig_5a.nc.PRtrend',
#  'CoupledModel.Fig_5a.nc.prTrend',
#  'CoupledModel.Fig_5a.nc.Qthtrend',
#  'CoupledModel.Fig_5a.nc.spClim',
#  'CoupledModel.Fig_5a.nc.tsClim',
#  'CoupledModel.Fig_5a.nc.tsTrend',
#  'CoupledModel.Fig_5a.nc.tstrend',
#  'CoupledModel.Fig_5a.nc.utrend',
#  'CoupledModel.Fig_5a.nc.vtrend',
#  'CoupledModel.Fig_5a.nc.wnspClim',
#  'CoupledModel.Fig_5b.nc.epsu',
#  'CoupledModel.Fig_5b.nc.epsv',
#  'CoupledModel.Fig_5b.nc.Hq',
#  'CoupledModel.Fig_5b.nc.K',
#  'CoupledModel.Fig_5b.nc.mask',
#  'CoupledModel.Fig_5b.nc.phitrend',
#  'CoupledModel.Fig_5b.nc.prClim',
#  'CoupledModel.Fig_5b.nc.PRtrend',
#  'CoupledModel.Fig_5b.nc.prTrend',
#  'CoupledModel.Fig_5b.nc.Qthtrend',
#  'CoupledModel.Fig_5b.nc.spClim',
#  'CoupledModel.Fig_5b.nc.tsClim',
#  'CoupledModel.Fig_5b.nc.tsTrend',
#  'CoupledModel.Fig_5b.nc.tstrend',
#  'CoupledModel.Fig_5b.nc.utrend',
#  'CoupledModel.Fig_5b.nc.vtrend',
#  'CoupledModel.Fig_5b.nc.wnspClim',
#  'CoupledModel.Fig_5c.nc.epsu',
#  'CoupledModel.Fig_5c.nc.epsv',
#  'CoupledModel.Fig_5c.nc.Hq',
#  'CoupledModel.Fig_5c.nc.K',
#  'CoupledModel.Fig_5c.nc.mask',
#  'CoupledModel.Fig_5c.nc.phitrend',
#  'CoupledModel.Fig_5c.nc.prClim',
#  'CoupledModel.Fig_5c.nc.PRtrend',
#  'CoupledModel.Fig_5c.nc.prTrend',
#  'CoupledModel.Fig_5c.nc.Qthtrend',
#  'CoupledModel.Fig_5c.nc.spClim',
#  'CoupledModel.Fig_5c.nc.tsClim',
#  'CoupledModel.Fig_5c.nc.tsTrend',
#  'CoupledModel.Fig_5c.nc.tstrend',
#  'CoupledModel.Fig_5c.nc.utrend',
#  'CoupledModel.Fig_5c.nc.vtrend',
#  'CoupledModel.Fig_5c.nc.wnspClim',
#  'CoupledModel.Fig_5d.nc.epsu',
#  'CoupledModel.Fig_5d.nc.epsv',
#  'CoupledModel.Fig_5d.nc.Hq',
#  'CoupledModel.Fig_5d.nc.K',
#  'CoupledModel.Fig_5d.nc.mask',
#  'CoupledModel.Fig_5d.nc.phitrend',
#  'CoupledModel.Fig_5d.nc.prClim',
#  'CoupledModel.Fig_5d.nc.PRtrend',
#  'CoupledModel.Fig_5d.nc.prTrend',
#  'CoupledModel.Fig_5d.nc.Qthtrend',
#  'CoupledModel.Fig_5d.nc.spClim',
#  'CoupledModel.Fig_5d.nc.tsClim',
#  'CoupledModel.Fig_5d.nc.tsTrend',
#  'CoupledModel.Fig_5d.nc.tstrend',
#  'CoupledModel.Fig_5d.nc.utrend',
#  'CoupledModel.Fig_5d.nc.vtrend',
#  'CoupledModel.Fig_5d.nc.wnspClim',
#  'CoupledModel.HTHERM-trend-Fig_4c.nc.HTHERM',
#  'CoupledModel.HTHERM-trend-Fig_5f.nc.HTHERM',
#  'CoupledModel.rh-Fig_5a.nc.rh',
#  'CoupledModel.rh-Fig_5b.nc.rh',
#  'CoupledModel.rh-Fig_5c.nc.rh',
#  'CoupledModel.rh-Fig_5d.nc.rh',
#  'ForcedAtmosphereModel.Fig_2c.nc.epsu',
#  'ForcedAtmosphereModel.Fig_2c.nc.epsv',
#  'ForcedAtmosphereModel.Fig_2c.nc.Hq',
#  'ForcedAtmosphereModel.Fig_2c.nc.K',
#  'ForcedAtmosphereModel.Fig_2c.nc.mask',
#  'ForcedAtmosphereModel.Fig_2c.nc.phitrend',
#  'ForcedAtmosphereModel.Fig_2c.nc.prClim',
#  'ForcedAtmosphereModel.Fig_2c.nc.PRtrend',
#  'ForcedAtmosphereModel.Fig_2c.nc.Qthtrend',
#  'ForcedAtmosphereModel.Fig_2c.nc.spClim',
#  'ForcedAtmosphereModel.Fig_2c.nc.tsClim',
#  'ForcedAtmosphereModel.Fig_2c.nc.tstrend',
#  'ForcedAtmosphereModel.Fig_2c.nc.utrend',
#  'ForcedAtmosphereModel.Fig_2c.nc.vtrend',
#  'ForcedAtmosphereModel.Fig_2c.nc.wnspClim',
#  'ForcedAtmosphereModel.Fig_2d.nc.epsu',
#  'ForcedAtmosphereModel.Fig_2d.nc.epsv',
#  'ForcedAtmosphereModel.Fig_2d.nc.Hq',
#  'ForcedAtmosphereModel.Fig_2d.nc.K',
#  'ForcedAtmosphereModel.Fig_2d.nc.mask',
#  'ForcedAtmosphereModel.Fig_2d.nc.phitrend',
#  'ForcedAtmosphereModel.Fig_2d.nc.prClim',
#  'ForcedAtmosphereModel.Fig_2d.nc.PRtrend',
#  'ForcedAtmosphereModel.Fig_2d.nc.Qthtrend',
#  'ForcedAtmosphereModel.Fig_2d.nc.spClim',
#  'ForcedAtmosphereModel.Fig_2d.nc.tsClim',
#  'ForcedAtmosphereModel.Fig_2d.nc.tstrend',
#  'ForcedAtmosphereModel.Fig_2d.nc.utrend',
#  'ForcedAtmosphereModel.Fig_2d.nc.vtrend',
#  'ForcedAtmosphereModel.Fig_2d.nc.wnspClim',
#  'ForcedOceanModel.HTHERM-trend-Fig_4b.nc.HTHERM',
#  'ForcedOceanModel.sst-trend-Fig_1d.nc.SST',
#  'ForcedOceanModel.sst-trend-Fig_1e.nc.SST',
#  'ForcedOceanModel.sst-trend-Fig_1f.nc.SST']

# %%
var_list
# Out:
# ['CoupledModel.Fig_3.nc.epsu',
#  'CoupledModel.Fig_3.nc.epsv',
#  'CoupledModel.Fig_3.nc.Hq',
#  'CoupledModel.Fig_3.nc.K',
#  'CoupledModel.Fig_3.nc.mask',
#  'CoupledModel.Fig_3.nc.phitrend',
#  'CoupledModel.Fig_3.nc.prClim',
#  'CoupledModel.Fig_3.nc.PRtrend',
#  'CoupledModel.Fig_3.nc.prTrend',
#  'CoupledModel.Fig_3.nc.Qthtrend',
#  'CoupledModel.Fig_3.nc.spClim',
#  'CoupledModel.Fig_3.nc.tsClim',
#  'CoupledModel.Fig_3.nc.tsTrend',
#  'CoupledModel.Fig_3.nc.tstrend',
#  'CoupledModel.Fig_3.nc.utrend',
#  'CoupledModel.Fig_3.nc.vtrend',
#  'CoupledModel.Fig_3.nc.wnspClim',
#  'CoupledModel.Fig_5a.nc.epsu',
#  'CoupledModel.Fig_5a.nc.epsv',
#  'CoupledModel.Fig_5a.nc.Hq',
#  'CoupledModel.Fig_5a.nc.K',
#  'CoupledModel.Fig_5a.nc.mask',
#  'CoupledModel.Fig_5a.nc.phitrend',
#  'CoupledModel.Fig_5a.nc.prClim',
#  'CoupledModel.Fig_5a.nc.PRtrend',
#  'CoupledModel.Fig_5a.nc.prTrend',
#  'CoupledModel.Fig_5a.nc.Qthtrend',
#  'CoupledModel.Fig_5a.nc.spClim',
#  'CoupledModel.Fig_5a.nc.tsClim',
#  'CoupledModel.Fig_5a.nc.tsTrend',
#  'CoupledModel.Fig_5a.nc.tstrend',
#  'CoupledModel.Fig_5a.nc.utrend',
#  'CoupledModel.Fig_5a.nc.vtrend',
#  'CoupledModel.Fig_5a.nc.wnspClim',
#  'CoupledModel.Fig_5b.nc.epsu',
#  'CoupledModel.Fig_5b.nc.epsv',
#  'CoupledModel.Fig_5b.nc.Hq',
#  'CoupledModel.Fig_5b.nc.K',
#  'CoupledModel.Fig_5b.nc.mask',
#  'CoupledModel.Fig_5b.nc.phitrend',
#  'CoupledModel.Fig_5b.nc.prClim',
#  'CoupledModel.Fig_5b.nc.PRtrend',
#  'CoupledModel.Fig_5b.nc.prTrend',
#  'CoupledModel.Fig_5b.nc.Qthtrend',
#  'CoupledModel.Fig_5b.nc.spClim',
#  'CoupledModel.Fig_5b.nc.tsClim',
#  'CoupledModel.Fig_5b.nc.tsTrend',
#  'CoupledModel.Fig_5b.nc.tstrend',
#  'CoupledModel.Fig_5b.nc.utrend',
#  'CoupledModel.Fig_5b.nc.vtrend',
#  'CoupledModel.Fig_5b.nc.wnspClim',
#  'CoupledModel.Fig_5c.nc.epsu',
#  'CoupledModel.Fig_5c.nc.epsv',
#  'CoupledModel.Fig_5c.nc.Hq',
#  'CoupledModel.Fig_5c.nc.K',
#  'CoupledModel.Fig_5c.nc.mask',
#  'CoupledModel.Fig_5c.nc.phitrend',
#  'CoupledModel.Fig_5c.nc.prClim',
#  'CoupledModel.Fig_5c.nc.PRtrend',
#  'CoupledModel.Fig_5c.nc.prTrend',
#  'CoupledModel.Fig_5c.nc.Qthtrend',
#  'CoupledModel.Fig_5c.nc.spClim',
#  'CoupledModel.Fig_5c.nc.tsClim',
#  'CoupledModel.Fig_5c.nc.tsTrend',
#  'CoupledModel.Fig_5c.nc.tstrend',
#  'CoupledModel.Fig_5c.nc.utrend',
#  'CoupledModel.Fig_5c.nc.vtrend',
#  'CoupledModel.Fig_5c.nc.wnspClim',
#  'CoupledModel.Fig_5d.nc.epsu',
#  'CoupledModel.Fig_5d.nc.epsv',
#  'CoupledModel.Fig_5d.nc.Hq',
#  'CoupledModel.Fig_5d.nc.K',
#  'CoupledModel.Fig_5d.nc.mask',
#  'CoupledModel.Fig_5d.nc.phitrend',
#  'CoupledModel.Fig_5d.nc.prClim',
#  'CoupledModel.Fig_5d.nc.PRtrend',
#  'CoupledModel.Fig_5d.nc.prTrend',
#  'CoupledModel.Fig_5d.nc.Qthtrend',
#  'CoupledModel.Fig_5d.nc.spClim',
#  'CoupledModel.Fig_5d.nc.tsClim',
#  'CoupledModel.Fig_5d.nc.tsTrend',
#  'CoupledModel.Fig_5d.nc.tstrend',
#  'CoupledModel.Fig_5d.nc.utrend',
#  'CoupledModel.Fig_5d.nc.vtrend',
#  'CoupledModel.Fig_5d.nc.wnspClim',
#  'CoupledModel.HTHERM-trend-Fig_4c.nc.HTHERM',
#  'CoupledModel.HTHERM-trend-Fig_5f.nc.HTHERM',
#  'CoupledModel.rh-Fig_5a.nc.rh',
#  'CoupledModel.rh-Fig_5b.nc.rh',
#  'CoupledModel.rh-Fig_5c.nc.rh',
#  'CoupledModel.rh-Fig_5d.nc.rh',
#  'ForcedAtmosphereModel.Fig_2c.nc.epsu',
#  'ForcedAtmosphereModel.Fig_2c.nc.epsv',
#  'ForcedAtmosphereModel.Fig_2c.nc.Hq',
#  'ForcedAtmosphereModel.Fig_2c.nc.K',
#  'ForcedAtmosphereModel.Fig_2c.nc.mask',
#  'ForcedAtmosphereModel.Fig_2c.nc.phitrend',
#  'ForcedAtmosphereModel.Fig_2c.nc.prClim',
#  'ForcedAtmosphereModel.Fig_2c.nc.PRtrend',
#  'ForcedAtmosphereModel.Fig_2c.nc.Qthtrend',
#  'ForcedAtmosphereModel.Fig_2c.nc.spClim',
#  'ForcedAtmosphereModel.Fig_2c.nc.tsClim',
#  'ForcedAtmosphereModel.Fig_2c.nc.tstrend',
#  'ForcedAtmosphereModel.Fig_2c.nc.utrend',
#  'ForcedAtmosphereModel.Fig_2c.nc.vtrend',
#  'ForcedAtmosphereModel.Fig_2c.nc.wnspClim',
#  'ForcedAtmosphereModel.Fig_2d.nc.epsu',
#  'ForcedAtmosphereModel.Fig_2d.nc.epsv',
#  'ForcedAtmosphereModel.Fig_2d.nc.Hq',
#  'ForcedAtmosphereModel.Fig_2d.nc.K',
#  'ForcedAtmosphereModel.Fig_2d.nc.mask',
#  'ForcedAtmosphereModel.Fig_2d.nc.phitrend',
#  'ForcedAtmosphereModel.Fig_2d.nc.prClim',
#  'ForcedAtmosphereModel.Fig_2d.nc.PRtrend',
#  'ForcedAtmosphereModel.Fig_2d.nc.Qthtrend',
#  'ForcedAtmosphereModel.Fig_2d.nc.spClim',
#  'ForcedAtmosphereModel.Fig_2d.nc.tsClim',
#  'ForcedAtmosphereModel.Fig_2d.nc.tstrend',
#  'ForcedAtmosphereModel.Fig_2d.nc.utrend',
#  'ForcedAtmosphereModel.Fig_2d.nc.vtrend',
#  'ForcedAtmosphereModel.Fig_2d.nc.wnspClim',
#  'ForcedOceanModel.HTHERM-trend-Fig_4b.nc.HTHERM',
#  'ForcedOceanModel.sst-trend-Fig_1d.nc.SST',
#  'ForcedOceanModel.sst-trend-Fig_1e.nc.SST',
#  'ForcedOceanModel.sst-trend-Fig_1f.nc.SST']

# %%
xr.open_dataset(FIGURE_DATA_PATH)['CoupledModel.HTHERM-trend-Fig_4c.nc.HTHERM'].plot()

# %%
xr.open_dataset(FIGURE_DATA_PATH)['ForcedOceanModel.HTHERM-trend-Fig_4b.nc.HTHERM'].plot()

# %%
xr.open_dataset(FIGURE_DATA_PATH)['ForcedOceanModel.HTHERM-trend-Fig_4b.nc.HTHERM'].sel(Y=slice(-30, 30), X_01=slice(50, 300)).plot()
