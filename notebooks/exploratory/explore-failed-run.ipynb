# %% [markdown]
# # Analysis

# %%
# Convenient jupyter setup
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.greedy=True

# %%
# set up plotting settings for dark mode.
from jupyterthemes import jtplot
jtplot.style(theme="grade3", context="notebook", ticks=True, grid=False)
from src.plot_utils import ps_defaults
ps_defaults(use_tex=False, dpi=150)

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
from src.models.model_setup import ModelSetup
from src.xr_utils import open_dataset, open_dataarray
from src.configs.load_config import load_config

# %%
import os

# %%
run_dir = (
    "/home/users/sithom/seager19/logs/full_58yr_sudden_freeze/"
    + "wandb/run-20210615_190008-1hvflplb/files"
)

# %%
run_dir = "/home/users/sithom/seager19/logs/ingrid_off/wandb/run-20210615_190934-2vo2fd4t/files"

# %%
cfg = load_config(test=False)
setup = ModelSetup(run_dir, cfg,  make_move=False)

# %%
run_dir
# Out:
# '/home/users/sithom/seager19/logs/ingrid_off/wandb/run-20210615_190934-2vo2fd4t/files'

# %%
open_dataarray(setup.ecmwf_sfcwind()).plot()

# %%
open_dataarray(setup.tau_x(it=1)).isel(T=1).plot()
