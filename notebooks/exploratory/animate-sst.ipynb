# %% [markdown]
# # Analysis

# %%
# Convenient jupyter setup
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.greedy=True
# Out:
# The autoreload module is not an IPython extension.
# UsageError: Line magic function `%autoreload` not found.

# %%
# set up plotting settings for dark mode.
from jupyterthemes import jtplot
jtplot.style(theme="grade3", context="notebook", ticks=True, grid=False)
from src.plot_settings import ps_defaults
ps_defaults(use_tex=False, dpi=150)
import xarray as xr
xr.set_options(display_style='text')

# %%
from src.constants import OCEAN_OUTPUT_PATH
from src.visualisation.ani import animate_xr_da

# %%
for x in [
    ["om_diag", {"T_01": "time", "Y_01": "y", "X_01": "x", "L_01": "Z"}],
    ["om_run2f", {"T_03": "time", "Y_03": "y", "X_03": "x", "L_03": "Z"}],
]:
    sst = xr.open_dataset(
        str(OCEAN_OUTPUT_PATH / x[0]) + ".nc", decode_times=False
    ).SST_SST.rename(x[1])
    sst.attrs["units"] = "degrees Celsius"
    animate_xr_da(sst.isel(Z=0), video_path=x[0] + "_SST.gif", vcmap="sst")
# Out:
# om_diag_SST.gif:   0%|          | 0/25 [00:00<?, ?it/s]
# om_diag_SST.gif:   4%|▍         | 1/25 [00:00<00:10,  2.32it/s]
# om_diag_SST.gif:   8%|▊         | 2/25 [00:00<00:09,  2.43it/s]
# om_diag_SST.gif:  12%|█▏        | 3/25 [00:01<00:07,  2.88it/s]
# om_diag_SST.gif:  16%|█▌        | 4/25 [00:01<00:06,  3.23it/s]
# om_diag_SST.gif:   0%|          | 0/25 [00:51<?, ?it/s].51it/s]
#
# om_diag_SST.gif:  24%|██▍       | 6/25 [00:01<00:05,  3.26it/s]
# om_diag_SST.gif:  28%|██▊       | 7/25 [00:02<00:05,  3.54it/s]
# om_diag_SST.gif:  32%|███▏      | 8/25 [00:02<00:04,  3.72it/s]
# om_diag_SST.gif:  36%|███▌      | 9/25 [00:02<00:04,  3.89it/s]
# om_diag_SST.gif:  40%|████      | 10/25 [00:03<00:04,  3.31it/s]
# om_diag_SST.gif:  44%|████▍     | 11/25 [00:03<00:04,  3.21it/s]
# om_diag_SST.gif:  48%|████▊     | 12/25 [00:03<00:03,  3.39it/s]
# om_diag_SST.gif:  52%|█████▏    | 13/25 [00:03<00:03,  3.56it/s]
# om_diag_SST.gif:  56%|█████▌    | 14/25 [00:04<00:03,  3.35it/s]
# om_diag_SST.gif:  60%|██████    | 15/25 [00:04<00:03,  2.99it/s]
# om_diag_SST.gif:  64%|██████▍   | 16/25 [00:05<00:03,  2.69it/s]
# om_diag_SST.gif:  68%|██████▊   | 17/25 [00:05<00:03,  2.47it/s]
# om_diag_SST.gif:  72%|███████▏  | 18/25 [00:06<00:02,  2.38it/s]
# om_diag_SST.gif:  76%|███████▌  | 19/25 [00:06<00:02,  2.52it/s]
# om_diag_SST.gif:  80%|████████  | 20/25 [00:06<00:02,  2.47it/s]
# om_diag_SST.gif:  84%|████████▍ | 21/25 [00:07<00:01,  2.47it/s]
# om_diag_SST.gif:  88%|████████▊ | 22/25 [00:07<00:01,  2.49it/s]
# om_diag_SST.gif:  92%|█████████▏| 23/25 [00:08<00:00,  2.39it/s]
# om_diag_SST.gif:  96%|█████████▌| 24/25 [00:08<00:00,  2.41it/s]
# om_diag_SST.gif: 100%|██████████| 25/25 [00:08<00:00,  2.86it/s]
# Video om_diag_SST.gif made.
# 'animate_xr_da'  11.10852 s
# om_run2f_SST.gif:  28%|██▊       | 194/697 [01:03<02:59,  2.81it/s]

# %%
sst.isel(time=600, Z=0).where(0.0)
# Out:
# -----------------------------------------------------
# IndexError          Traceback (most recent call last)
# <ipython-input-16-835b4a8fd6cc> in <module>
# ----> 1 sst.isel(time=600, Z=0).where(0.0)
#
# ~/seager19/env/lib/python3.8/site-packages/xarray/core/dataarray.py in isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1128         # lists, or zero or one-dimensional np.ndarray's
#    1129
# -> 1130         variable = self._variable.isel(indexers, missing_dims=missing_dims)
#    1131
#    1132         coords = {}
#
# ~/seager19/env/lib/python3.8/site-packages/xarray/core/variable.py in isel(self, indexers, missing_dims, **indexers_kwargs)
#    1164
#    1165         key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1166         return self[key]
#    1167
#    1168     def squeeze(self, dim=None):
#
# ~/seager19/env/lib/python3.8/site-packages/xarray/core/variable.py in __getitem__(self, key)
#     809         """
#     810         dims, indexer, new_order = self._broadcast_indexes(key)
# --> 811         data = as_indexable(self._data)[indexer]
#     812         if new_order:
#     813             data = duck_array_ops.moveaxis(data, range(len(new_order)), new_order)
#
# ~/seager19/env/lib/python3.8/site-packages/xarray/core/indexing.py in __getitem__(self, key)
#     695
#     696     def __getitem__(self, key):
# --> 697         return type(self)(_wrap_numpy_scalars(self.array[key]))
#     698
#     699     def transpose(self, order):
#
# ~/seager19/env/lib/python3.8/site-packages/xarray/core/indexing.py in __getitem__(self, key)
#    1300     def __getitem__(self, key):
#    1301         array, key = self._indexing_array_and_key(key)
# -> 1302         return array[key]
#    1303
#    1304     def __setitem__(self, key, value):
#
# IndexError: index 600 is out of bounds for axis 0 with size 25

# %%
 SST.where(SST!=0).isel(Z=0, time=650).plot()

# %%
dir(cmocean.absolute_import)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'compiler_flag',
#  'getMandatoryRelease',
#  'getOptionalRelease',
#  'mandatory',
#  'optional']

# %%
cmocean.cm.cmapnames
# Out:
# ['thermal',
#  'haline',
#  'solar',
#  'ice',
#  'gray',
#  'oxy',
#  'deep',
#  'dense',
#  'algae',
#  'matter',
#  'turbid',
#  'speed',
#  'amp',
#  'tempo',
#  'rain',
#  'phase',
#  'topo',
#  'balance',
#  'delta',
#  'curl',
#  'diff',
#  'tarn']

# %%
import cmocean

# %%
cmocean.cm.balance
