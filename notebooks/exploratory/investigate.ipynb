# %%
import os
from src.constants import ATMOS_DATA_PATH, DATA_PATH
import xarray as xr
import matplotlib.pyplot as plt

# %%
xr.open_dataarray(os.path.join(ATMOS_DATA_PATH, "rh-CMIP6-clim60.nc")).plot()

# %%
os.listdir(ATMOS_DATA_PATH)
# Out:
# ['ps-ECMWF-clim.nc',
#  'ts-ECMWF-clim60.nc',
#  'sfcWind-ECMWF-clim60.nc',
#  'pr-ECMWF-trend.nc',
#  'sst-ECMWF-clim.nc',
#  'mask-360x181.nc',
#  'ts-ECMWF-clim.nc',
#  'mask-360x180.nc',
#  'clt-ECMWF-clim60.nc',
#  'ts-ECMWF-trend.nc',
#  'sst-ECMWF-trend.nc',
#  'rh-fixed-clim60.nc',
#  'rh-ECMWF-clim60.nc',
#  'sfcWind-ECMWF-clim.nc',
#  'pr-ECMWF-clim.nc',
#  'rh-CMIP5-clim60.nc',
#  'sfcWind-CMIP5-clim.nc',
#  'sfcWind-CMIP5-clim60.nc',
#  'rh-CMIP6-clim60.nc',
#  'sfcWind-CMIP6-clim.nc',
#  'sfcWind-CMIP6-clim60.nc']

# %%
xr.open_dataarray(os.path.join(DATA_PATH, "nc_mean", "hur.nc")).plot()

# %%
xr.open_dataarray(os.path.join(DATA_PATH, "nc_mean", "wsp.nc")).plot()

# %%
import matplotlib.pyplot as plt

with plt.xkcd():
    # This figure will be in XKCD-style
    fig1 = plt.figure()
    plt.plot([0, 1], [1, 0])
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.xlabel("Data")
    plt.ylabel("Assumptions")
    plt.xticks([0])
    plt.yticks([0])
