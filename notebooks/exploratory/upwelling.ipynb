# %% [markdown]
# # Analysis

# %%
# Convenient jupyter setup
# %load_ext autoreload
# %autoreload 2
# %config IPCompleter.greedy=True

# %%
# set up plotting settings for dark mode.
from jupyterthemes import jtplot
jtplot.style(theme="grade3", context="notebook", ticks=True, grid=False)
from src.plot_utils import ps_defaults
ps_defaults(use_tex=False, dpi=150)

# %%
from src.models.model_setup import ModelSetup
from src.xr_utils import open_dataset, open_dataarray, can_coords
from src.configs.load_config import load_config
run_dir = "/home/users/sithom/seager19/logs/it_1"
cfg = load_config(test=False)
uncoup_setup = ModelSetup(run_dir, cfg,  make_move=False)

# %%
can_coords(open_dataset(uncoup_setup.om_run2f_nc()).SST_UP_FLUX).isel(T=600).plot()

# %%
var_list = []
for var in open_dataset(uncoup_setup.om_run2f_nc()):
    var_list.append(var)
print(var_list)
# Out:
# ['DYN_PRES', 'TDEEP_HTHERM', 'TDEEP_TDEEP', 'TDEEP_HMODEL', 'SST_SST', 'SST_W1', 'SST_UDTDX', 'SST_VDTDY', 'SST_UP_FLUX', 'SST_QPRIME', 'SST_QFC', 'SST_QNET']

# %%
can_coords(open_dataset(uncoup_setup.om_run2f_nc()).SST_QNET).isel(T=600).plot()

# %%
can_coords(open_dataset(uncoup_setup.om_run2f_nc()).SST_W1).isel(T=600).plot()

# %%
can_coords(open_dataset(uncoup_setup.om_run2f_nc()).SST_UP_FLUX).isel(T=600).plot()
