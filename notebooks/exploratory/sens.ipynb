# %%
import matplotlib.pyplot as plt

# %%
mem_d = {'EEEE': [[0.0, 0.002, 0.001, 0.003, 0.00125, 0.00175, 0.0015, 0.00225, 0.0025], [0.47880143558011756, 0.4419071401812645, 0.4620349949376124, 0.4177776365644564, 0.4573311573097827, 0.4473159304277305, 0.4524595661987653, 0.34383609480161137, 0.4308068541314366]], 'EECE': [[0.0, 0.00075, 0.001, 0.003, 0.002, 0.00125, 0.00175, 0.0015, 0.00225, 0.0025], [0.534204447579621, 0.5224171641117532, 0.5179559878365265, 0.4743281136053856, 0.4984771199206013, 0.5134679621583936, 0.5037712460987842, 0.5087431954948954, 0.49292485422488236, 0.4870302904972866]], 'EEEC': [[0.0, 0.001, 0.003, 0.002, 0.00125, 0.00175, 0.0015, 0.00225, 0.0025], [0.7926864451243943, 0.7907100205994677, 0.7711188579786774, 0.7857709079726033, 0.7902739311779488, 0.7881786001371319, 0.7895506485667015, 0.7829723088424907, 0.7796136060409287]], 'EECC': [[0.00025, 0.002, 0.0, 0.001, 0.00075, 0.003, 0.00125, 0.00275, 0.00175, 0.0015, 0.00225, 0.0025], [0.9312602109460774, 0.9467958710296477, 0.9281091455357844, 0.9395696739158838, 0.9366614381883928, 0.9467585554870136, 0.9418995337511764, 0.9471902758783822, 0.9455469781764494, 0.9438354073984287, 0.9477379133635063, 0.9477201488112674]]}

# %%
name_d = {"EEEE": "ECMWF world", "EECE": "CMIP5 W", "EEEC": "CMIP5 RH",  "EECC": "CMIP5 RH+W"}

for mem in name_d:
    plt.scatter(mem_d[mem][0], mem_d[mem][1], marker="x", label=name_d[mem])

plt.xlabel("Drag Coefficient, $C_d$")
plt.ylabel("1958-2017 Nino3.4 trend [K]")
plt.legend(
    bbox_to_anchor=(0.0, 1.02, 1, 0.102),
    loc="lower left",
    mode="expand",
    ncol=2,
)

# %%
mem_d ={'EEEE': [[0.0, 0.002, 0.001, 0.003, 0.00125, 0.00175, 0.0015, 0.00225, 0.0025], [0.47880143558011756, 0.4419071401812645, 0.4620349949376124, 0.4177776365644564, 0.4573311573097827, 0.4473159304277305, 0.4524595661987653, 0.43652271245097646, 0.4308068541314366]], 'EECE': [[0.0, 0.00075, 0.001, 0.003, 0.002, 0.00125, 0.00175, 0.0015, 0.00225, 0.0025], [0.534204447579621, 0.5224171641117532, 0.5179559878365265, 0.4743281136053856, 0.4984771199206013, 0.5134679621583936, 0.5037712460987842, 0.5087431954948954, 0.49292485422488236, 0.4870302904972866]], 'EEEC': [[0.0, 0.001, 0.003, 0.002, 0.00125, 0.00175, 0.0015, 0.00225, 0.0025], [0.7926864451243943, 0.7907100205994677, 0.7711188579786774, 0.7857709079726033, 0.7902739311779488, 0.7881786001371319, 0.7895506485667015, 0.7829723088424907, 0.7796136060409287]], 'EECC': [[0.00025, 0.002, 0.0, 0.001, 0.00075, 0.003, 0.00125, 0.00275, 0.00175, 0.0015, 0.00225, 0.0025], [0.9312602109460774, 0.9467958710296477, 0.9281091455357844, 0.9395696739158838, 0.9366614381883928, 0.9467585554870136, 0.9418995337511764, 0.9471902758783822, 0.9455469781764494, 0.9438354073984287, 0.9477379133635063, 0.9477201488112674]]}

# %%
# efrac=2
mem_d = {'EEEE': [[0.00025, 0.0], [0.4771924536031659, 0.47880143558011756]], 'EECE': [[0.00025, 0.0], [0.5331637297200497, 0.534204447579621]], 'EEEC': [[0.00025, 0.0], [0.7964640863884265, 0.7926864451243943]], 'EECC': [[0.00025, 0.0], [0.9362901169637091, 0.9281091455357844]]}

# %%
name_d = {"EEEE": "ECMWF world", "EECE": "CMIP5 W", "EEEC": "CMIP5 RH",  "EECC": "CMIP5 RH+W"}

for mem in name_d:
    plt.scatter(mem_d[mem][0], mem_d[mem][1], marker="x", label=name_d[mem])

plt.xlabel("Drag Coefficient, $C_d$")
plt.ylabel("1958-2017 Nino3.4 trend [K]")
plt.legend(
    bbox_to_anchor=(0.0, 1.02, 1, 0.102),
    loc="lower left",
    mode="expand",
    ncol=2,
)
